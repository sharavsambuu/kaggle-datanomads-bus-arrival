# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
bus_id_encoder     = pickle.load(open("./busnet_pickles/bus_id_encoder.pickle"    , "rb"))
route_id_encoder   = pickle.load(open("./busnet_pickles/route_id_encoder.pickle"  , "rb"))
busstop_id_encoder = pickle.load(open("./busnet_pickles/busstop_id_encoder.pickle", "rb"))

# %%
dataset_df  = pd.read_csv("./out/cleaned_train.csv")

# %%
dataset_df
# Out:
#          DAY_OF_WEEK  HOUR_OF_DAY  MINUTE_OF_HOUR  SECOND_OF_MINUTE   TIME  \
# 0                  0            7              28                25   5305
# 1                  0            7              30                22   5422
# 2                  0            7              32                25   5545
# 3                  0            7              34                26   5666
# 4                  0            7              36                42   5802
# ...              ...          ...             ...               ...    ...
# 3130654            6           22              27                 3  59223
# 3130655            6           22              29                 6  59346
# 3130656            6           22              32                11  59531
# 3130657            6           22              33                50  59630
# 3130658            6           22              37                35  59855
#
#          BUS_ID  BUSROUTE_ID  BUSSTOP_ID  TIMESTAMP_DIFF  ROUTE_TIME  SEQ_NUM
# 0             0            3          17           117.0    0.817500     21.0
# 1             0            3          10           123.0    0.817500     21.0
# 2             0            3           8           121.0    0.817500     21.0
# 3             0            3           5           136.0    0.817500     21.0
# 4             0            3           3           174.0    0.817500     21.0
# ...         ...          ...         ...             ...         ...      ...
# 3130654     995          271          10           123.0    0.903056     13.0
# 3130655     995          271           8           185.0    0.903056     13.0
# 3130656     995          271           5            99.0    0.903056     13.0
# 3130657     995          271           3           225.0    0.903056     13.0
# 3130658     995          271         146           150.0    0.903056     13.0
#
# [3130659 rows x 11 columns]

# %%
shot_df = pd.read_csv("./out/output_ready.csv")
shot_df
# Out:
#            index     TIMESTAMP
# 0        3220254  1.579685e+09
# 1        3220255  1.579685e+09
# 2        3220256  1.579685e+09
# 3        3220257  1.579685e+09
# 4        3220258  1.579685e+09
# ...          ...           ...
# 1557459  4777713  1.579884e+09
# 1557460  4777714  1.579887e+09
# 1557461  4777715  1.579887e+09
# 1557462  4777716  1.579888e+09
# 1557463  4777717  1.579888e+09
#
# [1557464 rows x 2 columns]

# %%
test_df = pd.read_csv("./data/test.csv")
test_df
# Out:
#            index  BUSROUTE_ID     BUS_ID  BUSSTOP_ID  BUSSTOP_SEQ  \
# 0        3220254     11100010       2054          11            3
# 1        3220255     11100010       2054           9            4
# 2        3220256     11100010       2054           6            5
# 3        3220257     11100010       2054           4            6
# 4        3220258     11100010       2054         147            7
# ...          ...          ...        ...         ...          ...
# 1557459  4777713     12100232  740518021         657            9
# 1557460  4777714     12100232  740518021         219            2
# 1557461  4777715     12100232  740518021         221            3
# 1557462  4777716     12100232  740518021         242            4
# 1557463  4777717     12100232  740518021         240            5
#
#                  RECORD_DATE     TIMESTAMP
# 0        2020-01-22 09:23:36  1.579685e+09
# 1                        NaN           NaN
# 2        2020-01-22 09:27:26  1.579685e+09
# 3                        NaN           NaN
# 4                        NaN           NaN
# ...                      ...           ...
# 1557459  2020-01-24 16:39:27  1.579884e+09
# 1557460  2020-01-24 17:28:00  1.579887e+09
# 1557461                  NaN           NaN
# 1557462                  NaN           NaN
# 1557463  2020-01-24 17:47:04  1.579888e+09
#
# [1557464 rows x 7 columns]

# %%
test_df['TIMESTAMP_FILLED'] = shot_df['TIMESTAMP']
test_df
# Out:
#            index  BUSROUTE_ID     BUS_ID  BUSSTOP_ID  BUSSTOP_SEQ  \
# 0        3220254     11100010       2054          11            3
# 1        3220255     11100010       2054           9            4
# 2        3220256     11100010       2054           6            5
# 3        3220257     11100010       2054           4            6
# 4        3220258     11100010       2054         147            7
# ...          ...          ...        ...         ...          ...
# 1557459  4777713     12100232  740518021         657            9
# 1557460  4777714     12100232  740518021         219            2
# 1557461  4777715     12100232  740518021         221            3
# 1557462  4777716     12100232  740518021         242            4
# 1557463  4777717     12100232  740518021         240            5
#
#                  RECORD_DATE     TIMESTAMP  TIMESTAMP_FILLED
# 0        2020-01-22 09:23:36  1.579685e+09      1.579685e+09
# 1                        NaN           NaN      1.579685e+09
# 2        2020-01-22 09:27:26  1.579685e+09      1.579685e+09
# 3                        NaN           NaN      1.579685e+09
# 4                        NaN           NaN      1.579685e+09
# ...                      ...           ...               ...
# 1557459  2020-01-24 16:39:27  1.579884e+09      1.579884e+09
# 1557460  2020-01-24 17:28:00  1.579887e+09      1.579887e+09
# 1557461                  NaN           NaN      1.579887e+09
# 1557462                  NaN           NaN      1.579888e+09
# 1557463  2020-01-24 17:47:04  1.579888e+09      1.579888e+09
#
# [1557464 rows x 8 columns]

# %%
test_df['TIMESTAMP_BK'] = test_df['TIMESTAMP']
test_df
# Out:
#            index  BUSROUTE_ID     BUS_ID  BUSSTOP_ID  BUSSTOP_SEQ  \
# 0        3220254     11100010       2054          11            3
# 1        3220255     11100010       2054           9            4
# 2        3220256     11100010       2054           6            5
# 3        3220257     11100010       2054           4            6
# 4        3220258     11100010       2054         147            7
# ...          ...          ...        ...         ...          ...
# 1557459  4777713     12100232  740518021         657            9
# 1557460  4777714     12100232  740518021         219            2
# 1557461  4777715     12100232  740518021         221            3
# 1557462  4777716     12100232  740518021         242            4
# 1557463  4777717     12100232  740518021         240            5
#
#                  RECORD_DATE     TIMESTAMP  TIMESTAMP_FILLED  TIMESTAMP_BK
# 0        2020-01-22 09:23:36  1.579685e+09      1.579685e+09  1.579685e+09
# 1                        NaN           NaN      1.579685e+09           NaN
# 2        2020-01-22 09:27:26  1.579685e+09      1.579685e+09  1.579685e+09
# 3                        NaN           NaN      1.579685e+09           NaN
# 4                        NaN           NaN      1.579685e+09           NaN
# ...                      ...           ...               ...           ...
# 1557459  2020-01-24 16:39:27  1.579884e+09      1.579884e+09  1.579884e+09
# 1557460  2020-01-24 17:28:00  1.579887e+09      1.579887e+09  1.579887e+09
# 1557461                  NaN           NaN      1.579887e+09           NaN
# 1557462                  NaN           NaN      1.579888e+09           NaN
# 1557463  2020-01-24 17:47:04  1.579888e+09      1.579888e+09  1.579888e+09
#
# [1557464 rows x 9 columns]

# %%
dataset_input = dataset_df[['DAY_OF_WEEK', 'TIME', 'BUS_ID', 'BUSROUTE_ID', 'BUSSTOP_ID']]
dataset_label = dataset_df[['TIMESTAMP_DIFF']]

# %%
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                        np.arange(d_model)[np.newaxis, :],
                        d_model)
    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    pos_encoding = angle_rads[np.newaxis, ...]
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
time_dim      = 64
total_seconds = 18*3600 # 18hours
pos_encoding  = positional_encoding(total_seconds, time_dim)
print(pos_encoding.shape)
# Out:
# (1, 64800, 64)

# %%
plt.pcolormesh(pos_encoding[0], cmap='RdBu')
plt.xlabel('Depth')
plt.xlim((0, time_dim))
plt.ylabel('Position')
plt.colorbar()
plt.show()

# %%
class BusNet(tf.keras.Model):
    def __init__(self, **kwargs):
        super(BusNet, self).__init__(**kwargs)

        self.week          = [0, 1, 2, 3, 4, 5, 6]
        self.time_dim      = 64
        self.time_count    = 18*3600

        self.bus_dim       = 32
        self.bus_count     = 1077

        self.route_dim     = 16
        self.route_count   = 353

        self.busstop_dim   = 32
        self.busstop_count = 1357

        self.dropout_rate  = 0.2

        self.day_of_week_embedding = tf.one_hot(self.week, len(self.week))
        self.time_embedding        = positional_encoding(self.time_count, self.time_dim)
        self.bus_embedding         = tf.keras.layers.Embedding(self.bus_count    , self.bus_dim    , embeddings_initializer='uniform', name='bus_embedding'    )
        self.route_embedding       = tf.keras.layers.Embedding(self.route_count  , self.route_dim  , embeddings_initializer='uniform', name='route_embedding'  )
        self.busstop_embedding     = tf.keras.layers.Embedding(self.busstop_count, self.busstop_dim, embeddings_initializer='uniform', name='busstop_embedding')

        self.layer_1      = tf.keras.layers.Dense(100, activation='relu')
        self.dropout_1    = tf.keras.layers.Dropout(self.dropout_rate)
        self.layer_2      = tf.keras.layers.Dense(64 , activation='relu')
        self.dropout_2    = tf.keras.layers.Dropout(self.dropout_rate)
        self.layer_3      = tf.keras.layers.Dense(32 , activation='relu')
        self.dropout_3    = tf.keras.layers.Dropout(self.dropout_rate)
        self.output_layer = tf.keras.layers.Dense(1)

    def call(self, inputs, training=True):
        days_of_week   = inputs[:, 0]
        time_positions = inputs[:, 1]
        bus_ids        = inputs[:, 2]
        route_ids      = inputs[:, 3]
        busstop_ids    = inputs[:, 4]

        day_vectors     = tf.convert_to_tensor([self.day_of_week_embedding[day] for day in days_of_week])
        time_vectors    = tf.convert_to_tensor([self.time_embedding[:, time_pos, :][0] for time_pos in time_positions], dtype=tf.float32)
        bus_vectors     = self.bus_embedding(bus_ids)
        route_vectors   = self.route_embedding(route_ids)
        busstop_vectors = self.busstop_embedding(busstop_ids)

        concatted_input = tf.concat([
          day_vectors  ,
          time_vectors , 
          bus_vectors  , 
          route_vectors, 
          busstop_vectors
          ], 1)

        x = self.layer_1(concatted_input)
        x = self.dropout_1(x, training=training)
        x = self.layer_2(x)
        x = self.dropout_2(x, training=training)
        x = self.layer_3(x)
        x = self.dropout_3(x, training=training)

        return self.output_layer(x)

# %%
model = BusNet(dynamic=True)

# %%
optimizer = tf.keras.optimizers.Adam()
ckpt      = tf.train.Checkpoint(step=tf.Variable(1), optimizer=optimizer, net=model)
manager   = tf.train.CheckpointManager(ckpt, './checkpoints', max_to_keep=3)

ckpt.restore(manager.latest_checkpoint)
if manager.latest_checkpoint:
    print("Restored from {}".format(manager.latest_checkpoint))
else:
    print("Initializing from scratch.")
# Out:
# Restored from ./checkpoints/ckpt-539

# %%
window_index = 50000
y = model(dataset_input[window_index-3:window_index+3].values, training=False)
print("predicted:")
print(y.numpy())
print("true values:")
print(dataset_label[window_index-3:window_index+3].values)

m = tf.keras.metrics.MeanAbsoluteError()
_ = m.update_state(y, dataset_label[window_index-3:window_index+3].values) 
print("mean absolute error:", m.result().numpy())
# Out:
# predicted:
# [[128.28285]
#  [135.97316]
#  [132.63171]
#  [112.54345]
#  [165.64857]
#  [114.27772]]
# true values:
# [[136.]
#  [123.]
#  [185.]
#  [106.]
#  [204.]
#  [124.]]
# mean absolute error: 21.279291

# %%
import random

cleaned_buses = dataset_df['BUS_ID'].unique()

# %%
def timestamp_to_dayofweek(time):
    return (time//3600//24 + 3) % 7

def timestamp_to_timeposition(time, starting_time = 21600): 
    if time < starting_time:
        return 0
    return (time - starting_time) % 86400

# %%
# ['DAY_OF_WEEK', 'TIME', 'BUS_ID', 'BUSROUTE_ID', 'BUSSTOP_ID']
for idx, row in test_df.iterrows():
    if (pd.isna(row['TIMESTAMP'])):
        prev_timestamp = test_df.iloc[idx-1]['TIMESTAMP_FILLED']
        prev_row       = test_df.iloc[idx-1]

        day_of_week   = int(timestamp_to_dayofweek(prev_timestamp))
        time_position = int(timestamp_to_timeposition(prev_timestamp))

        bus_id = int(prev_row['BUS_ID'])
        try:
            bus_position = bus_id_encoder.transform([bus_id])[0]
        except:
            bus_position = random.choice(cleaned_buses)

        route_id         = int(prev_row['BUSROUTE_ID'])
        route_position   = route_id_encoder.transform([route_id])[0]

        busstop_id       = int(prev_row['BUSSTOP_ID'])
        busstop_position = busstop_id_encoder.transform([busstop_id])[0]

        model_input = np.array([[day_of_week, time_position, bus_position, route_position, busstop_position]])
        prediction  = int(model(model_input, training=False))

        test_df.at[idx, 'DIFF'] = prediction

    if idx%5000==0:
        print("completed at", idx)
# Out:
# completed at 0
# completed at 5000
# completed at 10000
# completed at 15000
# completed at 20000
# completed at 25000
# completed at 30000
# completed at 35000
# completed at 40000
# completed at 45000
# completed at 50000
# completed at 55000
# completed at 60000
# completed at 65000
# completed at 70000
# completed at 75000
# completed at 80000
# completed at 85000
# completed at 90000
# completed at 95000
# completed at 100000
# completed at 105000
# completed at 110000
# completed at 115000
# completed at 120000
# completed at 125000
# completed at 130000
# completed at 135000
# completed at 140000
# completed at 145000
# completed at 150000
# completed at 155000
# completed at 160000
# completed at 165000
# completed at 170000
# completed at 175000
# completed at 180000
# completed at 185000
# completed at 190000
# completed at 195000
# completed at 200000
# completed at 205000
# completed at 210000
# completed at 215000
# completed at 220000
# completed at 225000
# completed at 230000
# completed at 235000
# completed at 240000
# completed at 245000
# completed at 250000
# completed at 255000
# completed at 260000
# completed at 265000
# completed at 270000
# completed at 275000
# completed at 280000
# completed at 285000
# completed at 290000
# completed at 295000
# completed at 300000
# completed at 305000
# completed at 310000
# completed at 315000
# completed at 320000
# completed at 325000
# completed at 330000
# completed at 335000
# completed at 340000
# completed at 345000
# completed at 350000
# completed at 355000
# completed at 360000
# completed at 365000
# completed at 370000
# completed at 375000
# completed at 380000
# completed at 385000
# completed at 390000
# completed at 395000
# completed at 400000
# completed at 405000
# completed at 410000
# completed at 415000
# completed at 420000
# completed at 425000
# completed at 430000
# completed at 435000
# completed at 440000
# completed at 445000
# completed at 450000
# completed at 455000
# completed at 460000
# completed at 465000
# completed at 470000
# completed at 475000
# completed at 480000
# completed at 485000
# completed at 490000
# completed at 495000
# completed at 500000
# completed at 505000
# completed at 510000
# completed at 515000
# completed at 520000
# completed at 525000
# completed at 530000
# completed at 535000
# completed at 540000
# completed at 545000
# completed at 550000
# completed at 555000
# completed at 560000
# completed at 565000
# completed at 570000
# completed at 575000
# completed at 580000
# completed at 585000
# completed at 590000
# completed at 595000
# completed at 600000
# completed at 605000
# completed at 610000
# completed at 615000
# completed at 620000
# completed at 625000
# completed at 630000
# completed at 635000
# completed at 640000
# completed at 645000
# completed at 650000
# completed at 655000
# completed at 660000
# completed at 665000
# completed at 670000
# completed at 675000
# completed at 680000
# completed at 685000
# completed at 690000
# completed at 695000
# completed at 700000
# completed at 705000
# completed at 710000
# completed at 715000
# completed at 720000
# completed at 725000
# completed at 730000
# completed at 735000
# completed at 740000
# completed at 745000
# completed at 750000
# completed at 755000
# completed at 760000
# completed at 765000
# completed at 770000
# completed at 775000
# completed at 780000
# completed at 785000
# completed at 790000
# completed at 795000
# completed at 800000
# completed at 805000
# completed at 810000
# completed at 815000
# completed at 820000
# completed at 825000
# completed at 830000
# completed at 835000
# completed at 840000
# completed at 845000
# completed at 850000
# completed at 855000
# completed at 860000
# completed at 865000
# completed at 870000
# completed at 875000
# completed at 880000
# completed at 885000
# completed at 890000
# completed at 895000
# completed at 900000
# completed at 905000
# completed at 910000
# completed at 915000
# completed at 920000
# completed at 925000
# completed at 930000
# completed at 935000
# completed at 940000
# completed at 945000
# completed at 950000
# completed at 955000
# completed at 960000
# completed at 965000
# completed at 970000
# completed at 975000
# completed at 980000

# %%
cnt = 0
for idx, row in test_df.iterrows():
    current_timestamp = row['TIMESTAMP_BK']
    if (pd.isna(current_timestamp)):
        next_timestamp = test_df.iloc[idx+1]['TIMESTAMP_BK']
        if (not pd.isna(next_timestamp)):
            day_of_week      = int(timestamp_to_dayofweek(row['TIMESTAMP_FILLED']))
            time_position    = int(timestamp_to_timeposition(row['TIMESTAMP_FILLED']))

            route_id         = int(row['BUSROUTE_ID'])
            route_position   = route_id_encoder.transform([route_id])[0]

            busstop_id       = int(row['BUSSTOP_ID'])
            busstop_position = busstop_id_encoder.transform([busstop_id])[0]
            
            bus_id = int(row['BUS_ID'])
            try:
                bus_position = bus_id_encoder.transform([bus_id])[0]
            except:
                try:
                    bus_position = random.choice(dataset_df[dataset_df['BUSSTOP_ID' ]==busstop_position]['BUS_ID'].unique().tolist())
                except:
                    bus_position = random.choice(cleaned_buses)
            
            model_input = np.array([[day_of_week, time_position, bus_position, route_position, busstop_position]])
            prediction  = int(model(model_input, training=False))
            
            test_df.at[idx+1, 'DIFF'] = prediction
            
            cnt = cnt+1
            if cnt%5000==0:
                print("processing at", idx)

# %%
test_df.to_csv("./out/test_reshoot_preadjustion.csv")

# %%
load_test_df = pd.read_csv("./out/test_reshoot_preadjustion.csv")
load_test_df.head(30)
